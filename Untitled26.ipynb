# %%
# !pip install accelerate
# !pip install bitsandbytes
# !pip install peft
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers import pipeline
from peft import PeftModel, PeftConfig

# %%
model_id = "Mukesh555/Llama-2-7b-chat-finetune"

# %%
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(model_id, load_in_8bit=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
pipe = pipeline("text-generation",
                model=model,
                tokenizer=tokenizer,
                max_new_tokens=2048,
)

# %%
prompt = "<human>Define CRIME?"

print(pipe(prompt))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-251f2391acb9> in <cell line: 3>()
#       1 prompt = "<human>Define CRIME?"
#       2
# ----> 3 print(pipe(prompt))
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     206               ids of the generated text.
#     207         """
# --> 208         return super().__call__(text_inputs, **kwargs)
#     209
#     210     def preprocess(
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1138             )
#    1139         else:
# -> 1140             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1141
# ...

# %%
prompt = "<human>:create documenation form by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?"

print(pipe(prompt))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1473: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use and modify the model generation configuration (see https://huggingface.co/docs/transformers/generation_strategies#default-text-generation-configuration )
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-d1e6d262e603> in <cell line: 3>()
#       1 prompt = "<human>:create documenation form by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?"
#       2
# ----> 3 print(pipe(prompt))
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
# ...

# %%
prompt = "<human>:create documenation form in 100 words with side headings by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?"

print(pipe(prompt))
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# ...

# %%
prompt = "<human>:create legal documenation form by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?"

print(pipe(prompt))
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# This is a friendly reminder - the current text generation call will exceed the model's predefined maximum length (2048). Depending on the model, you may observe exceptions, performance degradation, or nothing at all.
# ...

# %%
prompt = "<human>:create FIR documenation in words form by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?"

print(pipe(prompt))
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# This is a friendly reminder - the current text generation call will exceed the model's predefined maximum length (2048). Depending on the model, you may observe exceptions, performance degradation, or nothing at all.
# ...

# %%
Personal Injury Case

# %%
prompt = "<human>:create Personal Injury Case documenation form by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?"

print(pipe(prompt))
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# [{'generated_text': '<human>:create Personal Injury Case documenation form by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?\n<assistance>: John, a pedestrian, was hit by a car while crossing the street at a crosswalk. I declare under oath that I was not driving or operating any vehicle, and I had no intention of driving or operating any vehicle.\n<assistance>: (Assistance): Nothing to be declared.'}]

# %%
Employment Discrimination Case:

# %%
prompt = "<human>:create  documentation form in type of Employment Discrimination Case by taking victims statement is Sarah alleges gender-based discrimination in her workplace?"

print(pipe(prompt))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-53e82ef4ae07> in <cell line: 3>()
#       1 prompt = "<human>:create  documentation form in type of Employment Discrimination Case by taking victims statement is Sarah alleges gender-based discrimination in her workplace?"
#       2
# ----> 3 print(pipe(prompt))
#
# NameError: name 'pipe' is not defined

# %%
prompt = "<human>:create  documenation form in type of FIR by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?"

print(pipe(prompt))
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# [{'generated_text': "<human>:create  documenation form in type of FIR by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?\n<div>: Notice of Accidental Death due to vehicular accident, FIR number <numer>: In this case, John, a pedestrian, was hit by a car while crossing the street at a crosswalk. The driver, however, was not charged with any offense because the accident was caused by the victim's carelessness.\n<end>: In accordance with Rule 3, Criminal Procedure Code of Criminal Procedure, 1973, the case is hereby closed."}]

# %%
prompt = "<human>:create  100 words documenation form in type of FIR by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?"

print(pipe(prompt))
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# [{'generated_text': '<human>:create  100 words documenation form in type of FIR by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?\nVictim: This accident occurred on [date] when I was crossing the street at a crosswalk. I was in no way negligent or responsible for the accident. I would like to file an FIR to record this incident and get the driver of the car charged for any violations.'}]

# %%
prompt = "<human>:create  500 words documenation form in type of FIR by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?"

print(pipe(prompt))
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# ...

# %%
prompt = "<human>:create  500 words case file for legal proceedings  by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?"

print(pipe(prompt))
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# ...

# %%
prompt = "<human>:create  500 words FIR documenation form  by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?"

print(pipe(prompt))
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# ...

# %%
# !pip install transformers accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 2.0 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer
import transformers
import torch

model = "Mukesh555/Llama-2-7b-indian_lawyer_chat-finetune"
prompt = "What is a large language model?"

tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)

sequences = pipeline(
    f'[INST] {prompt} [/INST]',
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=200,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/434 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/635 [00:00<?, ?B/s]
# pytorch_model.bin.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# ...
# pytorch_model-00001-of-00002.bin:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/174 [00:00<?, ?B/s]
# ...

# %%
prompt = " define crime?"
sequences = pipeline(
    f'[INST] {prompt} [/INST]',
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=200,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result: [INST]  define crime? [/INST] A crime can be defined as an act or omission committed in violation of a written law that is punishable by the state or federal authorities.
#
# Crimes may be categorized as either felonies or misdemeanors. Felonies are those crimes that are punishable by more than one year in prison, while misdemeanors are those crimes that are punishable by less than one year in the state prison or by a fine.
#
# Crime can also involve the violation of a law or rule that is not necessarily written, such as the breaking of a social norm or expectation, or the violation of an ethical or moral code.
#
# In addition to criminal laws, crimes may also be defined by international or national treaties, or by the rules of a particular organization or institution.
#
# Overall, the definition of crime is complex and can vary depending

# %%
prompt = "create  500 words case file for legal proceedings  by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?"
sequences = pipeline(
    f'[INST] {prompt} [/INST]',
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=200,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result: [INST] create  500 words case file for legal proceedings  by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk? [/INST] Case File: John v.1. Motor Vehicle Owner
#
# Background: John, a 36-year-old resident of New York City, was hit by a speeding car while crossing the street at a crosswalk. The incident occurred on March 15, 2023, at around 9 am.
#
# Issue: Whether the motor vehicle owner and the driver are liable for the injuries sustained by the victim in the accident.
#
# Facts:
#
# 1. John was crossing the street at a designated crosswalk when he was struck by a speeding car driven by X.
# 2. The car failed to stop at a red light before hitting John, resulting in severe inj

# %%
prompt = "create FIR Document by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?"
sequences = pipeline(
    f'[INST] {prompt} [/INST]',
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=2000,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result: [INST] create FIR Document by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk? [/INST] Victim statement:
# .
# I am John, a pedestrian who was hit by a car while crossing the street at a crosswalk. My statement is to inform the authorities of the accident and to provide a detailed account of the events leading up to and following the incident.
#
# I was crossing the street at a designated crosswalk when the car struck me. I suffered moderate injuries and was taken to a nearby hospital for medical treatment.
#
# I believe that the driver of the car was negligent and failed to yield the right of way at the crosswalk, causing the accident. I demand justice and compensation for the injuries sustained in the incident.
#
# I have attached photographic evidence of the accident scene, including photographs of the damage to the car and the injuries sustained by me.
#
# Sincerely,
#
# John
#
# Victim's Signature: John

# %%
prompt = "create  500 words case file for legal proceedings  by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk?"
sequences = pipeline(
    f'[INST] {prompt} [/INST]',
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=2000,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result: [INST] create  500 words case file for legal proceedings  by taking victims statement is John, a pedestrian, was hit by a car while crossing the street at a crosswalk? [/INST] Victim Statement:
# , John, a pedestrian who was hit by a car while crossing the street at a crosswalk, describes the incident as devastating and traumatic. He recounts how the driver of the car failed to stop at the crosswalk and struck him with its vehicle, causing serious injuries. He emphasizes the need for stricter traffic laws and regulations to prevent such accidents in the future.
#
# Legal Argument:
#
# , John's victim statement highlights the need for better driver training and compliance with traffic laws to prevent pedestrian accidents. John's legal team could argue that the driver of the car in the incident violated the rights of pedestrians by failing to stop at the crosswalk and failing to show due care and attention.
#
# ...

# %%
prompt = "Can you provide some sections and laws that are used by lawyers"
sequences = pipeline(
    f'[INST] {prompt} [/INST]',
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=2000,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result: [INST] Can you provide some sections and laws that are used by lawyers [/INST] Sure! Here are some laws and regulations that are often used by lawyers:
# 1. Constitution of India: The Constitution of India sets out the basic structure of the Indian legal system, including the rights and duties of individuals, the powers of the government, and the relationship between the federal and state governments.
# 2. Indian Contract Act, 1872: The Indian Contract Act sets out the rules for the formation, performance, and enforcement of contracts in India.
# 3. Indian Penal Code, 1837: The Indian Penal Code sets out the provisions for criminal law in India, including the punishments for various crimes.
# 4. Civil Procedure Code, 1908: The Civil Procedure Code sets out the rules for civil litigation in India, including the procedures for filing lawsuits, serving notice, and conducting trials.
# ...

# %%
#What is section 498 a of Indian penal code?
prompt = "What is section 498 a of Indian penal code?"
sequences = pipeline(
    f'[INST] {prompt} [/INST]',
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=2000,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result: [INST] What is section 498 a of Indian penal code? [/INST] 498-A of Indian Penal Code deals with "Husband or relative of husband subjecting a woman to cruelty." This section was enacted in 1970 to criminalize the act of subjecting a woman to cruelty by her husband or any relative of her husband. Punishment for violation of this section includes imprisonment for a term which may extend to 3 years and also to pay a fine.
#
# The law was enacted to protect the rights of women in India and to curb the practice of cruelty meted out to them by their husbands or relatives. Since its enactment, this law has been instrumental in protecting the rights of women and in maintaining law and order in the country.
#
# ...

# %%
prompt = "What is the Judgement of 498A"
sequences = pipeline(
    f'[INST] {prompt} [/INST]',
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=2000,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Result: [INST] What is the Judgement of 498A [/INST] The case of 498A of the Indian Penal Code, 1860, is a landmark case in India related to domestic violence.
#
# In this case, a man was charged with and later convicted of murdering his wife, who was a victim of domestic violence. The court held that Section 302 (punishment for murder) and Section 149 (punishment for criminal conspiracy) of the IPC applied to this case, and the accused was accordingly sentenced to death.
#
# ...

# %%
prompt = "tell me about section 420?"
sequences = pipeline(
    f'[INST] {prompt} [/INST]',
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=2000,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result: [INST] tell me about section 420? [/INST] As an AI language model, I don't have the authority to advise people or give legal advice.
# It is crucial to consult a legal professional for advice on how to interpret and apply the law.
#
# In general, Section 420 of the Indian Penal Code (IPC) pertains to the offense of "criminal intimidation." It is defined under IPC Section 420 as a criminal act that involves threatening or attempting to threaten someone in order to cause harm or apprehension to that person or a third party.
#
# Penalties for committing the offense of criminal intimidation vary depending on the specific circumstances of the offense and the severity of the harm caused. For example, criminal intimidation can be punished with a prison term of up to two years or with a fine, or both, under IPC Section 420
#
# ...
